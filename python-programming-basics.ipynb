# %% [markdown]
# <a href="https://www.kaggle.com/code/mehvishashiq/python-programming-basics?scriptVersionId=110629309" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Python Programming From Beginner to Advanced Level — Basics

# %% [markdown]
# ## 2.1 Output

# %%
print("Hi! how are you?") #getting expected output
# Out:
# Hi! how are you?

# %%
print(Hi! how are you) #getting unexpected output
# Out:
#   File "/tmp/ipykernel_5321/4007610148.py", line 1
#     print(Hi! how are you) #getting unexpected output
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2.2 Input

# %%
input("Enter a number:") #get intput from a user
# Out:
# Enter a number: 3
# '3'

# %% [markdown]
# ## 2.3 Variable

# %%
#string type value can be written in single/double qoutes
first_name = "Mehvish"
last_name = 'Ashiq'
print(first_name + " " + last_name) # we can get the same output using as print(first_name, last_name)
print(f'FirstName: {first_name} LastName: {last_name}') #using f-string to format string
# Out:
# Mehvish Ashiq
# FirstName: Mehvish LastName: Ashiq

# %%
#prompts the user to enter a number
number = input("Enter a number: ")

#print the type of the number
print(type(number))

#change the type of number to integer and print it
print(type(int(number)))
# Out:
# Enter a number:  6
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ## 2.4 Data Types

# %% [markdown]
# ### Numbers

# %%
int_number = 30
float_number = 30.05
complex_number = 5+6j

print(int_number, float_number, complex_number)
print(type(int_number), type(float_number), type(complex_number))
# Out:
# 30 30.05 (5+6j)
# <class 'int'> <class 'float'> <class 'complex'>

# %%
print(3+5) # we are adding two numbers using plus operator
print(5-3) # we subtract one number from the other using subtraction operator
print(5*3) # we multiply one number with the other using multiplication operator
print(10/3) # we perform division using divide operator
print(5%3) # we use modulus operator to get a remainder
print(2**2) # we use exponentiation operator to perform 2 raise to power 2 (2^2)
print(5//3) # Here, we use floor division, which rounds the result down to a nearest whole number
# Out:
# 8
# 2
# 15
# 3.3333333333333335
# 2
# 4
# 1

# %% [markdown]
# ### String

# %%
character = 'c'
print(character, type(character))
# Out:
# c <class 'str'>

# %%
first_name = "Mehvish"
print("Hi, I'm: " + first_name)
print('Hi, I\'m: ' + first_name)
# Out:
# Hi, I'm: Mehvish
# Hi, I'm: Mehvish

# %%
#enclosing string within three quotes will allow us to print on multiple lines
message = """Hi, are you learning Python?
Can you help me because I'm also learning it?
"""

print(message)
# Out:
# Hi, are you learning Python?
# Can you help me because I'm also learning it?

# %%
message = "Hello World"
print(len(message)) # len() returns the length of string.
print(message[0]) # get character at index 0
print(message[1:3]) # get characters starting from index 1 (including) to index 3 (excluding)
print(message[:3]) # get characters starting from index 0 to 3 (where index 3 is not included)
print(message[3:]) # get characters starting from index 3 till the last index
# Out:
# 11
# H
# el
# Hel
# lo World

# %%
print(message.count('o')) # returns the count of the given character
print(message.lower()) # transforms all characters to lower-case
print(message.upper()) # transforms all characters to upper-case
print(message.find('Hello')) # returns the starting index of the specified word
# Out:
# 2
# hello world
# HELLO WORLD
# 0

# %%
full_name = "Tahir Raza"
print(full_name)

full_name = full_name[:6]  + "Ashiq" # update string by accessing the index
print(full_name)

full_name = full_name.replace("Ashiq", "Raza") # udpate string using built-in method
print(full_name)
# Out:
# Tahir Raza
# Tahir Ashiq
# Tahir Raza

# %%
message = "Hello"
print(message + "Python") # we concatenate the value of message variable with "Python"
print(message*3) # we print the value of message thrice
print(message[1]) # we retrieve and print the value at index 1
print(message[2:3]) # we retrieve and print the value starting form index 2 to 3 where index 3 is excluded
print("H" in message) # check if "H" is in message, if it is so, we'll get true otherwise false
print("Y" not in message) # check if "Y" is not in message, if it is so, we'll get true otherwise false
print("I'm %s and learning %s" % ("Mehvish", "Python")) # use formatting operator to concatenate various types of data
# Out:
# HelloPython
# HelloHelloHello
# e
# l
# True
# True
# I'm Mehvish and learning Python

# %% [markdown]
# ### Boolean

# %%
print(1<3) # returns true if condition is satisfied
print(2<=3) # returns true if condition is satisfied
print("Mehvish" != "Mehvish") # returns true if both sides are not equal
print("Mehvish" == "Mehvish") # returns true if both sides are equal
print((2>4) or (5>2)) # returns true if anyone condition fulfills
print((2>4) and (5>2)) # retursn true if both conditions are satisfied
# Out:
# True
# True
# False
# True
# True
# False

# %% [markdown]
# ### List

# %%
my_list = ["Mehvish", 23, 34.89, True]
print(my_list)

print(len(my_list)) #returns the length of the list (number of elements with the list)
print(type(my_list)) #returns type
print(my_list[0]) #retrieve value at index 0
print(my_list[1:3]) #here index 1 is included and index 3 is excluded that's why we are getting values at index 1 and 2
# Out:
# ['Mehvish', 23, 34.89, True]
# 4
# <class 'list'>
# Mehvish
# [23, 34.89]

# %%
mylist = list(("Mehvish", 23, 34.89, True))

print(len(mylist)) #length of the list
print(type(mylist)) #print type
print(mylist[1:3]) #access list values
print(mylist)

mylist[1] = 34 #update list value at index 1
print(mylist)

mylist.append("New Element") #update list by appending an element
print(mylist)

del mylist[4] #delement element at index 4
print(mylist)
# Out:
# 4
# <class 'list'>
# [23, 34.89]
# ['Mehvish', 23, 34.89, True]
# ['Mehvish', 34, 34.89, True]
# ['Mehvish', 34, 34.89, True, 'New Element']
# ['Mehvish', 34, 34.89, True]

# %% [markdown]
# ### Dictionary

# %%
dictionary = {'Name': "Thomas", 'Name': "Christopher", 'Age': 56}
print(dictionary) #print dictionary values
print(dictionary['Name']) #access dictionary value and print it
# Out:
# {'Name': 'Christopher', 'Age': 56}
# Christopher

# %%
dictionary = {'Name': "Thomas", 'School': "ABC School", 'Age': 56}
print(dictionary['Name']) #access dictionary value and print it

dictionary['School'] = "XYZ School" #update dictionary value at given key
print(dictionary)

del dictionary['Age'] #delete individual element
print(dictionary)

dictionary.clear() #clear the whole dictionary
print(dictionary)
# Out:
# Thomas
# {'Name': 'Thomas', 'School': 'XYZ School', 'Age': 56}
# {'Name': 'Thomas', 'School': 'XYZ School'}
# {}

# %% [markdown]
# ### Tuple

# %%
empty_tuple = ()
tuple_with_one_element = ('Hi',)
tuple_with_multiple_elements = ('Mehvish', 45, 'Computer Science', 2014)
tuple_with_duplicate_elements = ('Hi', 'Hi')

print(empty_tuple)
print(tuple_with_one_element)
print(tuple_with_multiple_elements)
print(tuple_with_duplicate_elements)
# Out:
# ()
# ('Hi',)
# ('Mehvish', 45, 'Computer Science', 2014)
# ('Hi', 'Hi')

# %%
tup = ('Mehvish', 45, 'Computer Science', 2014)

print(tup[1]) #get and print value from index 1
print(tup[1:3]) #get and print value from index 1 (incldued) to 3 (excluded)
print(tup[:3]) #get and print value from index 0 (incldued) to 3 (excluded)
print(tup[:4]) #get and print value from index 0 (incldued) to 4 (excluded)
print(tup[0:]) #get and print value from index 0 (incldued) to n-1
# Out:
# 45
# (45, 'Computer Science')
# ('Mehvish', 45, 'Computer Science')
# ('Mehvish', 45, 'Computer Science', 2014)
# ('Mehvish', 45, 'Computer Science', 2014)

# %%
tup1 = ('Mehvish', 45, 'Computer Science')
tup2 = ('This is',)
tup3 = tup1 + tup2
print(tup3)

tup3 = tup2 + tup1
print(tup3)

del tup1
print(tup1)
# Out:
# ('Mehvish', 45, 'Computer Science', 'This is')
# ('This is', 'Mehvish', 45, 'Computer Science')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5321/2256115035.py in <module>
#       8
#       9 del tup1
# ---> 10 print(tup1)
#
# NameError: name 'tup1' is not defined

# %% [markdown]
# ### Sets

# %%
set1 = {"Mehvish", "Tahir", "Thomas"}
set2 = {"John", "Jenni", "Saira"}

print(type(set1))
print(type(set2))

print("The union of set1 and set2 is given below:")
print(set1.union(set2))
# Out:
# <class 'set'>
# <class 'set'>
# The union of set1 and set2 is given below:
# {'Jenni', 'Saira', 'Mehvish', 'Thomas', 'John', 'Tahir'}

# %%
print(set1)
set1.add("Daniel") #add single item in set1
print(set1)
# Out:
# {'Thomas', 'Tahir', 'Mehvish'}
# {'Thomas', 'Daniel', 'Tahir', 'Mehvish'}

# %%
print(set1)
list1 = ["1", "Saira", 23.34] #create list
set1.update(list1) # use list to add multiple items in set1
print(set1)
# Out:
# {'Thomas', 'Daniel', 'Tahir', 'Mehvish'}
# {'Saira', 'Mehvish', 'Daniel', 23.34, '1', 'Thomas', 'Tahir'}

# %%
set1 = {"Thomas", "John"}
print(set1)
set1.discard("Mehvish") #it will note generate any error
# Out:
# {'Thomas', 'John'}

# %%
set1 = {"Thomas", "John"}
print(set1)
set1.remove("Mehvish") #it will generate the KeyError
# Out:
# {'Thomas', 'John'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5321/288000698.py in <module>
#       1 set1 = {"Thomas", "John"}
#       2 print(set1)
# ----> 3 set1.remove("Mehvish") #it will generate the KeyError
#
# KeyError: 'Mehvish'

# %% [markdown]
# ## 2.5 Conditionals

# %% [markdown]
# ### if-else Statement

# %%
#if the number is even, the if statement
# would be executed

number =10

if(number%2 == 0):
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
num1 = 5
num2 = 4

if(num1 > num2):
    message = "The num1 is greater than the num2"
    print(message)
    
elif (num1 < num2):
    message = "The num1 is less than the num2"
    print(message)
    
else:
    message = "The num1 is equal to the num2"
    print(message)
# Out:
# The num1 is greater than the num2

# %%
total = 100
country = "PK"

if(country == "US"):
    if(total <= 50):
        print("Shipping Cost = $50")
elif(total <= 100 or country == "PK"):
    print("Shipping Cost = $25")
elif(total <= 150 or country == "AU"):
    print("Shipping Cost = $5")
else:
    print("FREE")
# Out:
# Shipping Cost = $25

# %% [markdown]
# ### switch Statement (match keyword)

# %%
#it will work in python 3.10 and above
colour = "yellow"
match colour:
    case "white":
        print("The specified colour is white")
    case "green":
        print("Wow, you've picked green")
    case "blue":
        print("Great, you are going with blue colour")
    case "yellow":
        print("Yellow like mango...")
    case other:
        print("No match found!")
# Out:
#   File "/tmp/ipykernel_5321/2568418937.py", line 3
#     match colour:
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2.6 Loops

# %% [markdown]
# ### while loop

# %%
# print the value of i until it is less than 6
i = 1
while i < 6:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# the break statement is used when we want the while
# loop to stop even if the condition is true. See the 
# following example, where we want to stop the while
# loop even if the i is less than 6. As soon as the
# loop reaches i==3, it breaks and ignores all upcoming 
# statements

i = 0
while i<6:
    i+=1
    if(i==3):
        break
    print(i)
# Out:
# 1
# 2

# %%
# By using the continue statement, we can stop the
# current iteration and continue with the next. Considering
# the following example, we ignore the iteration when i==3,
# and continue with the later iterations.

i = 0
while i<6:
    i+=1
    if(i==3):
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# ### for loop

# %%
# here we are also iterating to print the value of i
# ranging from 0 to 6 using for loop (6 is not included here)
for i in range(6):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# the range(start, stop, step) values are 
# range (1,6,2) to start printing from 1,
# increment by 2 each time. Remember, the
# endpoint is excluded

for i in range(1,6,2):
    print(i)
# Out:
# 1
# 3
# 5

# %% [markdown]
# ## 2.7 Functions

# %%
def add_numbers(number1, number2):
    return number1+number2

sum_of_numbers = add_numbers(3,2)
print("The sum is " + str(sum_of_numbers)) # converting to string to concatenate using + operator
print(f'The sum is {sum_of_numbers}') # concatenating using f-string, no need to convert to string data type
# Out:
# The sum is 5
# The sum is 5
